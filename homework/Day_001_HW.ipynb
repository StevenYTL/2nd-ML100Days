# %% [markdown]
# ### 作業一
# ------
# 我所選用的Dataset為: Amazon Alexa Reviews
# 網址:https://www.kaggle.com/sid321axn/amazon-alexa-reviews
#
# Q1. 你選的這組資料為何重要
# * 近年來電子商務的崛起，已經造成大部分人們都在網路上消費，線上消費是一個既方便又快速的消費模式。然而，這種消費模式雖然簡單，但是無法實際上接觸到產品的；因此許多人在線上購買產品之前，都會先去觀看其他使用者的消費評論(customer reivew)，透過評論來決定是否購買。而越來越多的評論產生，形成了資訊過載的問題；以世界知名電商Amazon為例，單一個產品就有上千上萬個評論，這使消費者很難有時間閱讀完且可能會只有接收到部分評論的資訊。因此，要如何去使顧客快速地了解到評論內容是個重要的問題。
#
# Q2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# * Kaggle網站上得來，以爬蟲程式所得到。
#
# Q3. 蒐集而來的資料型態為何
# * tsv，有五個欄位，分別為rating(int)、date(string)、variation(string)、verified_reviews(string)、feedback(boolean)
#
# Q4. 這組資料想解決的問題如何評估
# * 可去評估評論屬於正向或負向？

# %% [markdown]
# ### 作業二
# ---
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
# Q1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# * 分配人力問題:熱門時段分配多點人、熱門區域分配多點人
#
# Q2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# * 大眾運輸工具的網站:EX，可看哪幾班火車有較多乘客
#
# Q3. 蒐集而來的資料型態為何
# * 時間(string)、平均乘客數(int)
#
# Q4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# * 透過實際載到的人數以及業績，進而評估。

# %% [markdown]
# ### 作業三

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

MAE = mean_absolute_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean absolute error is 11.724

# %% [markdown]
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse
MSE = mean_squared_error(y, y_hat)
print("The Mean absolute error is %.3f" % (MSE))
# Out:
# The Mean absolute error is 218.846

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 218.846
# The Mean absolute error is 11.724
